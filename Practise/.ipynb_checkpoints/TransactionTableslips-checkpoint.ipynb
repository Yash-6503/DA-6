# %%
#slip6
'''Create the following dataset in python & Convert the categorical values into numeric format.Apply
the apriori algorithm on the above dataset to generate the frequent itemsets and association rules. Repeat
the process with different min_sup values. '''
import pandas as pd
from mlxtend.preprocessing import TransactionEncoder
from mlxtend.frequent_patterns import apriori, association_rules
#createthedataset
TID={1:['bread','milk'],2:['bread','diaper','beer','eggs'],3:['milk','diaper','beer','coke'],4:['bread','milk','diaper','beer'],5:['bread','milk','diaper','coke']}
Transactions=[]
for key,value in TID.items():
    Transactions.append(value)
#convertthecategoricalvaluesintonumericformat
Te=TransactionEncoder()
Te_ary=Te.fit_transform(Transactions)
Df=pd.DataFrame(Te_ary,columns=Te.columns_)
#applytheapriorialgorithmwithdifferentmin_supvalues
Min_sup_values=[0.2,0.4,0.6]
for min_sup in Min_sup_values:
    Frequent_itemsets=apriori(Df,min_support=min_sup,use_colnames=True)
    Rules=association_rules(Frequent_itemsets, metric = 'confidence', min_threshold=0.7)
    print('Min_sup:',min_sup)
    print('FrequentItemsets:')
    print(Frequent_itemsets)
    print('AssociationRules:')
    print(Rules)
# Out:
# Min_sup: 0.2
# FrequentItemsets:
#     support                     itemsets
# 0       0.6                       (beer)
# 1       0.8                      (bread)
# 2       0.4                       (coke)
# 3       0.8                     (diaper)
# 4       0.2                       (eggs)
# 5       0.8                       (milk)
# 6       0.4                (beer, bread)
# 7       0.2                 (coke, beer)
# 8       0.6               (diaper, beer)
# 9       0.2                 (beer, eggs)
# 10      0.4                 (beer, milk)
# 11      0.2                (coke, bread)
# 12      0.6              (diaper, bread)
# 13      0.2                (eggs, bread)
# 14      0.6                (milk, bread)
# 15      0.4               (coke, diaper)
# 16      0.4                 (coke, milk)
# 17      0.2               (diaper, eggs)
# 18      0.6               (diaper, milk)
# 19      0.4        (diaper, beer, bread)
# 20      0.2          (beer, eggs, bread)
# 21      0.2          (beer, milk, bread)
# 22      0.2         (coke, diaper, beer)
# 23      0.2           (coke, beer, milk)
# 24      0.2         (diaper, beer, eggs)
# 25      0.4         (diaper, beer, milk)
# 26      0.2        (coke, diaper, bread)
# 27      0.2          (coke, milk, bread)
# 28      0.2        (diaper, eggs, bread)
# 29      0.4        (diaper, milk, bread)
# 30      0.4         (coke, diaper, milk)
# 31      0.2  (diaper, beer, eggs, bread)
# 32      0.2  (diaper, beer, milk, bread)
# 33      0.2   (coke, diaper, beer, milk)
# 34      0.2  (coke, diaper, milk, bread)
# AssociationRules:
#               antecedents            consequents  antecedent support  \
# 0                (diaper)                 (beer)                 0.8
# 1                  (beer)               (diaper)                 0.6
# 2                  (eggs)                 (beer)                 0.2
# 3                (diaper)                (bread)                 0.8
# 4                 (bread)               (diaper)                 0.8
# 5                  (eggs)                (bread)                 0.2
# 6                  (milk)                (bread)                 0.8
# 7                 (bread)                 (milk)                 0.8
# 8                  (coke)               (diaper)                 0.4
# 9                  (coke)                 (milk)                 0.4
# 10                 (eggs)               (diaper)                 0.2
# 11               (diaper)                 (milk)                 0.8
# 12                 (milk)               (diaper)                 0.8
# 13          (beer, bread)               (diaper)                 0.4
# 14           (beer, eggs)                (bread)                 0.2
# 15          (eggs, bread)                 (beer)                 0.2
# 16                 (eggs)          (beer, bread)                 0.2
# 17           (coke, beer)               (diaper)                 0.2
# 18           (coke, beer)                 (milk)                 0.2
# 19         (diaper, eggs)                 (beer)                 0.2
# 20           (beer, eggs)               (diaper)                 0.2
# 21                 (eggs)         (diaper, beer)                 0.2
# 22           (beer, milk)               (diaper)                 0.4
# 23          (coke, bread)               (diaper)                 0.2
# 24          (coke, bread)                 (milk)                 0.2
# 25         (diaper, eggs)                (bread)                 0.2
# 26          (eggs, bread)               (diaper)                 0.2
# 27                 (eggs)        (diaper, bread)                 0.2
# 28         (coke, diaper)                 (milk)                 0.4
# 29           (coke, milk)               (diaper)                 0.4
# 30                 (coke)         (diaper, milk)                 0.4
# 31   (diaper, beer, eggs)                (bread)                 0.2
# 32  (diaper, eggs, bread)                 (beer)                 0.2
# 33    (beer, eggs, bread)               (diaper)                 0.2
# 34         (diaper, eggs)          (beer, bread)                 0.2
# 35           (beer, eggs)        (diaper, bread)                 0.2
# 36          (eggs, bread)         (diaper, beer)                 0.2
# 37                 (eggs)  (diaper, beer, bread)                 0.2
# 38    (beer, milk, bread)               (diaper)                 0.2
# 39   (coke, diaper, beer)                 (milk)                 0.2
# 40     (coke, beer, milk)               (diaper)                 0.2
# 41           (coke, beer)         (diaper, milk)                 0.2
# 42  (coke, diaper, bread)                 (milk)                 0.2
# 43    (coke, milk, bread)               (diaper)                 0.2
# 44          (coke, bread)         (diaper, milk)                 0.2
#
#     consequent support  support  confidence      lift  leverage  conviction  \
# 0                  0.6      0.6        0.75  1.250000      0.12         1.6
# 1                  0.8      0.6        1.00  1.250000      0.12         inf
# 2                  0.6      0.2        1.00  1.666667      0.08         inf
# 3                  0.8      0.6        0.75  0.937500     -0.04         0.8
# 4                  0.8      0.6        0.75  0.937500     -0.04         0.8
# 5                  0.8      0.2        1.00  1.250000      0.04         inf
# 6                  0.8      0.6        0.75  0.937500     -0.04         0.8
# 7                  0.8      0.6        0.75  0.937500     -0.04         0.8
# 8                  0.8      0.4        1.00  1.250000      0.08         inf
# 9                  0.8      0.4        1.00  1.250000      0.08         inf
# 10                 0.8      0.2        1.00  1.250000      0.04         inf
# 11                 0.8      0.6        0.75  0.937500     -0.04         0.8
# 12                 0.8      0.6        0.75  0.937500     -0.04         0.8
# 13                 0.8      0.4        1.00  1.250000      0.08         inf
# 14                 0.8      0.2        1.00  1.250000      0.04         inf
# 15                 0.6      0.2        1.00  1.666667      0.08         inf
# 16                 0.4      0.2        1.00  2.500000      0.12         inf
# 17                 0.8      0.2        1.00  1.250000      0.04         inf
# 18                 0.8      0.2        1.00  1.250000      0.04         inf
# 19                 0.6      0.2        1.00  1.666667      0.08         inf
# 20                 0.8      0.2        1.00  1.250000      0.04         inf
# 21                 0.6      0.2        1.00  1.666667      0.08         inf
# 22                 0.8      0.4        1.00  1.250000      0.08         inf
# 23                 0.8      0.2        1.00  1.250000      0.04         inf
# 24                 0.8      0.2        1.00  1.250000      0.04         inf
# 25                 0.8      0.2        1.00  1.250000      0.04         inf
# 26                 0.8      0.2        1.00  1.250000      0.04         inf
# 27                 0.6      0.2        1.00  1.666667      0.08         inf
# 28                 0.8      0.4        1.00  1.250000      0.08         inf
# 29                 0.8      0.4        1.00  1.250000      0.08         inf
# 30                 0.6      0.4        1.00  1.666667      0.16         inf
# 31                 0.8      0.2        1.00  1.250000      0.04         inf
# 32                 0.6      0.2        1.00  1.666667      0.08         inf
# 33                 0.8      0.2        1.00  1.250000      0.04         inf
# 34                 0.4      0.2        1.00  2.500000      0.12         inf
# 35                 0.6      0.2        1.00  1.666667      0.08         inf
# 36                 0.6      0.2        1.00  1.666667      0.08         inf
# 37                 0.4      0.2        1.00  2.500000      0.12         inf
# 38                 0.8      0.2        1.00  1.250000      0.04         inf
# 39                 0.8      0.2        1.00  1.250000      0.04         inf
# 40                 0.8      0.2        1.00  1.250000      0.04         inf
# 41                 0.6      0.2        1.00  1.666667      0.08         inf
# 42                 0.8      0.2        1.00  1.250000      0.04         inf
# 43                 0.8      0.2        1.00  1.250000      0.04         inf
# 44                 0.6      0.2        1.00  1.666667      0.08         inf
#
#     zhangs_metric
# 0        1.000000
# 1        0.500000
# 2        0.500000
# 3       -0.250000
# 4       -0.250000
# 5        0.250000
# 6       -0.250000
# 7       -0.250000
# 8        0.333333
# 9        0.333333
# 10       0.250000
# 11      -0.250000
# 12      -0.250000
# 13       0.333333
# 14       0.250000
# 15       0.500000
# 16       0.750000
# 17       0.250000
# 18       0.250000
# 19       0.500000
# 20       0.250000
# 21       0.500000
# 22       0.333333
# 23       0.250000
# 24       0.250000
# 25       0.250000
# 26       0.250000
# 27       0.500000
# 28       0.333333
# 29       0.333333
# 30       0.666667
# 31       0.250000
# 32       0.500000
# 33       0.250000
# 34       0.750000
# 35       0.500000
# 36       0.500000
# 37       0.750000
# 38       0.250000
# 39       0.250000
# 40       0.250000
# 41       0.500000
# 42       0.250000
# 43       0.250000
# 44       0.500000
# Min_sup: 0.4
# FrequentItemsets:
#     support               itemsets
# 0       0.6                 (beer)
# 1       0.8                (bread)
# 2       0.4                 (coke)
# 3       0.8               (diaper)
# 4       0.8                 (milk)
# 5       0.4          (beer, bread)
# 6       0.6         (diaper, beer)
# 7       0.4           (beer, milk)
# 8       0.6        (diaper, bread)
# 9       0.6          (milk, bread)
# 10      0.4         (coke, diaper)
# 11      0.4           (coke, milk)
# 12      0.6         (diaper, milk)
# 13      0.4  (diaper, beer, bread)
# 14      0.4   (diaper, beer, milk)
# 15      0.4  (diaper, milk, bread)
# 16      0.4   (coke, diaper, milk)
# AssociationRules:
#        antecedents     consequents  antecedent support  consequent support  \
# 0         (diaper)          (beer)                 0.8                 0.6
# 1           (beer)        (diaper)                 0.6                 0.8
# 2         (diaper)         (bread)                 0.8                 0.8
# 3          (bread)        (diaper)                 0.8                 0.8
# 4           (milk)         (bread)                 0.8                 0.8
# 5          (bread)          (milk)                 0.8                 0.8
# 6           (coke)        (diaper)                 0.4                 0.8
# 7           (coke)          (milk)                 0.4                 0.8
# 8         (diaper)          (milk)                 0.8                 0.8
# 9           (milk)        (diaper)                 0.8                 0.8
# 10   (beer, bread)        (diaper)                 0.4                 0.8
# 11    (beer, milk)        (diaper)                 0.4                 0.8
# 12  (coke, diaper)          (milk)                 0.4                 0.8
# 13    (coke, milk)        (diaper)                 0.4                 0.8
# 14          (coke)  (diaper, milk)                 0.4                 0.6
#
#     support  confidence      lift  leverage  conviction  zhangs_metric
# 0       0.6        0.75  1.250000      0.12         1.6       1.000000
# 1       0.6        1.00  1.250000      0.12         inf       0.500000
# 2       0.6        0.75  0.937500     -0.04         0.8      -0.250000
# 3       0.6        0.75  0.937500     -0.04         0.8      -0.250000
# 4       0.6        0.75  0.937500     -0.04         0.8      -0.250000
# 5       0.6        0.75  0.937500     -0.04         0.8      -0.250000
# 6       0.4        1.00  1.250000      0.08         inf       0.333333
# 7       0.4        1.00  1.250000      0.08         inf       0.333333
# 8       0.6        0.75  0.937500     -0.04         0.8      -0.250000
# 9       0.6        0.75  0.937500     -0.04         0.8      -0.250000
# 10      0.4        1.00  1.250000      0.08         inf       0.333333
# 11      0.4        1.00  1.250000      0.08         inf       0.333333
# 12      0.4        1.00  1.250000      0.08         inf       0.333333
# 13      0.4        1.00  1.250000      0.08         inf       0.333333
# 14      0.4        1.00  1.666667      0.16         inf       0.666667
# Min_sup: 0.6
# FrequentItemsets:
#    support         itemsets
# 0      0.6           (beer)
# 1      0.8          (bread)
# 2      0.8         (diaper)
# 3      0.8           (milk)
# 4      0.6   (diaper, beer)
# 5      0.6  (diaper, bread)
# 6      0.6    (milk, bread)
# 7      0.6   (diaper, milk)
# AssociationRules:
#   antecedents consequents  antecedent support  consequent support  support  \
# 0    (diaper)      (beer)                 0.8                 0.6      0.6
# 1      (beer)    (diaper)                 0.6                 0.8      0.6
# 2    (diaper)     (bread)                 0.8                 0.8      0.6
# 3     (bread)    (diaper)                 0.8                 0.8      0.6
# 4      (milk)     (bread)                 0.8                 0.8      0.6
# 5     (bread)      (milk)                 0.8                 0.8      0.6
# 6    (diaper)      (milk)                 0.8                 0.8      0.6
# 7      (milk)    (diaper)                 0.8                 0.8      0.6
#
#    confidence    lift  leverage  conviction  zhangs_metric
# 0        0.75  1.2500      0.12         1.6           1.00
# 1        1.00  1.2500      0.12         inf           0.50
# 2        0.75  0.9375     -0.04         0.8          -0.25
# 3        0.75  0.9375     -0.04         0.8          -0.25
# 4        0.75  0.9375     -0.04         0.8          -0.25
# 5        0.75  0.9375     -0.04         0.8          -0.25
# 6        0.75  0.9375     -0.04         0.8          -0.25
# 7        0.75  0.9375     -0.04         0.8          -0.25

# %%
#slip10
import pandas as pd
from mlxtend.preprocessing import TransactionEncoder
from mlxtend.frequent_patterns import apriori, association_rules
#Createthedataset
Dataset={
1:['eggs','milk','bread'],
2:['eggs','apple'],
3:['milk','bread'],
4:['apple','milk'],
5:['milk','apple','bread']
}
#Convertcategoricalvaluesintonumericformat
Te=TransactionEncoder()
Te_ary=Te.fit(Dataset.values()).transform(Dataset.values())
Df=pd.DataFrame(Te_ary,columns=Te.columns_)
#ApplyApriorialgorithmtogeneratefrequentitemsetsandassociationrulesMin_sup=0.4
Frequent_itemsets=apriori(Df,min_support=min_sup,use_colnames=True)
Association_rules=association_rules(Frequent_itemsets,metric='confidence',min_threshold=0.6)
#Printthefrequentitemsetsandassociationrules
print('FrequentItemsets:\n',Frequent_itemsets)
print('\nAssociationRules:\n',Association_rules)
# Out:
# FrequentItemsets:
#     support       itemsets
# 0      0.6        (apple)
# 1      0.6        (bread)
# 2      0.8         (milk)
# 3      0.6  (milk, bread)
#
# AssociationRules:
#    antecedents consequents  antecedent support  consequent support  support  \
# 0      (milk)     (bread)                 0.8                 0.6      0.6
# 1     (bread)      (milk)                 0.6                 0.8      0.6
#
#    confidence  lift  leverage  conviction  zhangs_metric
# 0        0.75  1.25      0.12         1.6            1.0
# 1        1.00  1.25      0.12         inf            0.5

# %%
#slip14
from mlxtend.preprocessing import TransactionEncoder
from mlxtend.frequent_patterns import apriori
#Createthedataset
TID={1:['apple','mango','banana'],
2:['mango','banana','cabbage','carrots'],
3:['mango','banana','carrots'],
4:['mango','carrots']}
#Convertthecategoricalvaluesintonumericformat
Te=TransactionEncoder()
Te_ary=te.fit([TID[i]for i in TID]).transform([TID[i]for i in TID])
Df=pd.DataFrame(Te_ary,columns=Te.columns_)
#Applytheapriorialgorithmwithdifferentmin_supvalues
Min_sup_values=[0.25,0.5,0.75]
for min_sup in min_sup_values:
    Frequent_itemsets=apriori(Df, min_support = min_sup, use_colnames=True)
    print('Frequent_itemsets with min_sup=',min_sup)
    print(Frequent_itemsets)
    print('\n')
# Out:
#   Cell In[21], line 17
#     print(“Frequent_itemsets with min_sup=”,min_sup)
#           ^
# SyntaxError: invalid character '“' (U+201C)
